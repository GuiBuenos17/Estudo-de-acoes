# %% [markdown]
# # 1. Importação de bibliotecas

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import RobustScaler
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, classification_report, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Carregamento dos dados

# %%
train_data = pd.read_csv('treino.csv')
test_data = pd.read_csv('teste.csv')

# %% [markdown]
# # 3. Seleção de colunas e normalização dos dados

# %%
past_close_columns = [f'Past_{i}_Days_Close' for i in range(1, 16)]
X_train = train_data[past_close_columns].values
X_test = test_data[past_close_columns].values

# %% [markdown]
# # 3.1 RobustScaler com range ajustado

# %%
scaler = RobustScaler(quantile_range=(1, 99))
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # 4. Criação de sequências e aumento de dados

# %%
def create_sequences(data, labels, time_steps=15):
    X, y = [], []
    for i in range(time_steps, len(data)):
        sequence = data[i - time_steps:i]
        X.append(sequence)
        y.append(labels[i])

        # Data augmentation melhorada
        if labels[i] == 1:
            # Adiciona ruído gaussiano
            noisy_sequence = sequence + np.random.normal(0, 0.005, sequence.shape)
            X.append(noisy_sequence)
            y.append(labels[i])

            # Time warping
            warped_sequence = sequence * (1 + np.random.uniform(-0.02, 0.02))
            X.append(warped_sequence)
            y.append(labels[i])

            # Amplitude scaling
            scaled_sequence = sequence * np.random.uniform(0.98, 1.02)
            X.append(scaled_sequence)
            y.append(labels[i])

    return np.array(X), np.array(y)

# %% [markdown]
# # 4.1 Criação de sequências para treino e teste

# %%
X_train_seq, y_train = create_sequences(X_train_scaled, train_data['Label'].values)
X_test_seq, y_test = create_sequences(X_test_scaled, test_data['Label'].values)

# %% [markdown]
# # 4.2 Conversão de rótulos

# %%
y_train = np.where(y_train == -1, 0, y_train)
y_test = np.where(y_test == -1, 0, y_test)

# %% [markdown]
# # 5. Cálculo dos pesos de classe

# %%
class_weights = compute_class_weight('balanced', classes=np.array([0, 1]), y=y_train)
class_weight_dict = {0: class_weights[0] * 1.2, 1: class_weights[1]}  # Aumento do peso da classe minoritária

# %% [markdown]
# # 6. Criação do modelo LSTM aprimorado

# %%
def create_model():
    model = Sequential([
        # Primeira camada LSTM com mais unidades
        Bidirectional(LSTM(256, return_sequences=True, kernel_regularizer='l2'),
                     input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])),
        BatchNormalization(),
        Dropout(0.3),

        # Segunda camada LSTM
        Bidirectional(LSTM(128, return_sequences=True, kernel_regularizer='l2')),
        BatchNormalization(),
        Dropout(0.3),

        # Terceira camada LSTM
        Bidirectional(LSTM(64, return_sequences=False, kernel_regularizer='l2')),
        BatchNormalization(),
        Dropout(0.2),

        # Camadas densas com regularização
        Dense(128, activation='relu', kernel_regularizer='l2'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(64, activation='relu', kernel_regularizer='l2'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(32, activation='relu', kernel_regularizer='l2'),
        BatchNormalization(),
        Dropout(0.1),

        Dense(1, activation='sigmoid')
    ])

    optimizer = Adam(learning_rate=0.0005)  # Learning rate reduzido
    model.compile(optimizer=optimizer,
                 loss='binary_crossentropy',
                 metrics=['accuracy'])
    return model

# %% [markdown]
# # 7. Configuração dos callbacks

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,  # Aumentado
    restore_best_weights=True,
    min_delta=0.0005
)

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,  # Redução mais suave
    patience=8,
    min_lr=0.000001,
    verbose=1
)

# %%
model_checkpoint = ModelCheckpoint(
    'best_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max'
)

# %% [markdown]
# # 8. Treinamento de modelos em ensemble

# %%
n_models = 7  # Aumentado número de modelos
models = []

# %%
for i in range(n_models):
    print(f"Training model {i+1}/{n_models}")
    model = create_model()


    history = model.fit(
        X_train_seq, y_train,
        epochs=200,  # Aumentado
        batch_size=32,  # Reduzido
        validation_split=0.2,
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        class_weight=class_weight_dict,
        verbose=1
    )
    models.append(model)
# Out:
# Training model 1/7
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 93s 271ms/step - accuracy: 0.4997 - loss: 16.5010 - val_accuracy: 0.7334 - val_loss: 9.0405 - learning_rate: 5.0000e-04
# Epoch 2/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 76s 251ms/step - accuracy: 0.4989 - loss: 7.9604 - val_accuracy: 0.4132 - val_loss: 5.1985 - learning_rate: 5.0000e-04
# Epoch 3/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 83s 254ms/step - accuracy: 0.5397 - loss: 4.6752 - val_accuracy: 0.5985 - val_loss: 3.9308 - learning_rate: 5.0000e-04
# Epoch 4/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 81s 250ms/step - accuracy: 0.5870 - loss: 3.2404 - val_accuracy: 0.3323 - val_loss: 2.9951 - learning_rate: 5.0000e-04
# Epoch 5/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 84s 257ms/step - accuracy: 0.6103 - loss: 2.4042 - val_accuracy: 0.8395 - val_loss: 1.8464 - learning_rate: 5.0000e-04
# Epoch 6/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 84s 266ms/step - accuracy: 0.6587 - loss: 1.8506 - val_accuracy: 0.8993 - val_loss: 1.3538 - learning_rate: 5.0000e-04
# Epoch 7/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 80s 260ms/step - accuracy: 0.6904 - loss: 1.4810 - val_accuracy: 0.3674 - val_loss: 2.4951 - learning_rate: 5.0000e-04
# Epoch 8/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 84s 267ms/step - accuracy: 0.7410 - loss: 1.1723 - val_accuracy: 0.9141 - val_loss: 0.8003 - learning_rate: 5.0000e-04
# Epoch 9/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 80s 261ms/step - accuracy: 0.7341 - loss: 0.9978 - val_accuracy: 0.8975 - val_loss: 0.6744 - learning_rate: 5.0000e-04
# Epoch 10/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 72s 258ms/step - accuracy: 0.7370 - loss: 0.8849 - val_accuracy: 0.8404 - val_loss: 0.7594 - learning_rate: 5.0000e-04
# Epoch 11/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 84s 265ms/step - accuracy: 0.7774 - loss: 0.7514 - val_accuracy: 0.5958 - val_loss: 0.9231 - learning_rate: 5.0000e-04
# Epoch 12/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 81s 260ms/step - accuracy: 0.7594 - loss: 0.7225 - val_accuracy: 0.6722 - val_loss: 0.6019 - learning_rate: 5.0000e-04
# Epoch 13/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 82s 259ms/step - accuracy: 0.7698 - loss: 0.6601 - val_accuracy: 0.9060 - val_loss: 0.4761 - learning_rate: 5.0000e-04
# Epoch 14/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 72s 259ms/step - accuracy: 0.7697 - loss: 0.6312 - val_accuracy: 0.8939 - val_loss: 0.4180 - learning_rate: 5.0000e-04
# Epoch 15/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 82s 259ms/step - accuracy: 0.7812 - loss: 0.6272 - val_accuracy: 0.9299 - val_loss: 0.3608 - learning_rate: 5.0000e-04
# Epoch 16/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 72s 259ms/step - accuracy: 0.7994 - loss: 0.5937 - val_accuracy: 0.3984 - val_loss: 1.3948 - learning_rate: 5.0000e-04
# Epoch 17/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 86s 274ms/step - accuracy: 0.7666 - loss: 0.6417 - val_accuracy: 0.8921 - val_loss: 0.4168 - learning_rate: 5.0000e-04
# Epoch 18/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 79s 263ms/step - accuracy: 0.7884 - loss: 0.5799 - val_accuracy: 0.4879 - val_loss: 0.9521 - learning_rate: 5.0000e-04
# Epoch 19/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 81s 258ms/step - accuracy: 0.7735 - loss: 0.6083 - val_accuracy: 0.8575 - val_loss: 0.5280 - learning_rate: 5.0000e-04
# Epoch 20/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 82s 259ms/step - accuracy: 0.7799 - loss: 0.5978 - val_accuracy: 0.2662 - val_loss: 1.4632 - learning_rate: 5.0000e-04
# Epoch 21/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 81s 257ms/step - accuracy: 0.7868 - loss: 0.5721 - val_accuracy: 0.7563 - val_loss: 0.6225 - learning_rate: 5.0000e-04
# Epoch 22/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 81s 255ms/step - accuracy: 0.7851 - loss: 0.5727 - val_accuracy: 0.9186 - val_loss: 0.3277 - learning_rate: 5.0000e-04
# Epoch 23/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 71s 257ms/step - accuracy: 0.7900 - loss: 0.5803 - val_accuracy: 0.7154 - val_loss: 0.6558 - learning_rate: 5.0000e-04
# Epoch 24/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 82s 256ms/step - accuracy: 0.7758 - loss: 0.5684 - val_accuracy: 0.8170 - val_loss: 0.5335 - learning_rate: 5.0000e-04
# Epoch 25/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 72s 259ms/step - accuracy: 0.7946 - loss: 0.5511 - val_accuracy: 0.9038 - val_loss: 0.4085 - learning_rate: 5.0000e-04
# Epoch 26/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 72s 258ms/step - accuracy: 0.7784 - loss: 0.5880 - val_accuracy: 0.5045 - val_loss: 0.8395 - learning_rate: 5.0000e-04
# Epoch 27/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 73s 262ms/step - accuracy: 0.7866 - loss: 0.5702 - val_accuracy: 0.9411 - val_loss: 0.2853 - learning_rate: 5.0000e-04
# Epoch 28/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 81s 260ms/step - accuracy: 0.7716 - loss: 0.5785 - val_accuracy: 0.8943 - val_loss: 0.3424 - learning_rate: 5.0000e-04
# Epoch 29/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 82s 261ms/step - accuracy: 0.7793 - loss: 0.5768 - val_accuracy: 0.8543 - val_loss: 0.4318 - learning_rate: 5.0000e-04
# Epoch 30/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 71s 257ms/step - accuracy: 0.8075 - loss: 0.5425 - val_accuracy: 0.9335 - val_loss: 0.2795 - learning_rate: 5.0000e-04
# Epoch 31/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 82s 256ms/step - accuracy: 0.8077 - loss: 0.5242 - val_accuracy: 0.6538 - val_loss: 0.8457 - learning_rate: 5.0000e-04
# Epoch 32/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 71s 256ms/step - accuracy: 0.7913 - loss: 0.5468 - val_accuracy: 0.3772 - val_loss: 1.0581 - learning_rate: 5.0000e-04
# Epoch 33/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 81s 253ms/step - accuracy: 0.7810 - loss: 0.5855 - val_accuracy: 0.5868 - val_loss: 1.3727 - learning_rate: 5.0000e-04
# Epoch 34/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 82s 254ms/step - accuracy: 0.8116 - loss: 0.5520 - val_accuracy: 0.9218 - val_loss: 0.3046 - learning_rate: 5.0000e-04
# Epoch 35/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 71s 255ms/step - accuracy: 0.7954 - loss: 0.5199 - val_accuracy: 0.6933 - val_loss: 0.9261 - learning_rate: 5.0000e-04
# Epoch 36/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 81s 253ms/step - accuracy: 0.8138 - loss: 0.5118 - val_accuracy: 0.7585 - val_loss: 0.5530 - learning_rate: 5.0000e-04
# Epoch 37/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 82s 254ms/step - accuracy: 0.8031 - loss: 0.5157 - val_accuracy: 0.8930 - val_loss: 0.4012 - learning_rate: 5.0000e-04
# Epoch 38/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.8103 - loss: 0.5195
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 80s 248ms/step - accuracy: 0.8103 - loss: 0.5195 - val_accuracy: 0.7230 - val_loss: 0.6369 - learning_rate: 5.0000e-04
# Epoch 39/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 83s 251ms/step - accuracy: 0.8237 - loss: 0.4911 - val_accuracy: 0.8404 - val_loss: 0.4332 - learning_rate: 1.0000e-04
# Epoch 40/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 84s 257ms/step - accuracy: 0.8220 - loss: 0.4779 - val_accuracy: 0.7644 - val_loss: 0.6861 - learning_rate: 1.0000e-04
# Epoch 41/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 82s 258ms/step - accuracy: 0.8355 - loss: 0.4553 - val_accuracy: 0.9456 - val_loss: 0.2237 - learning_rate: 1.0000e-04
# Epoch 42/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 81s 255ms/step - accuracy: 0.8262 - loss: 0.4544 - val_accuracy: 0.8930 - val_loss: 0.3362 - learning_rate: 1.0000e-04
# Epoch 43/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 71s 254ms/step - accuracy: 0.8233 - loss: 0.4527 - val_accuracy: 0.9159 - val_loss: 0.2891 - learning_rate: 1.0000e-04
# Epoch 44/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 81s
200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 83s 258ms/step - accuracy: 0.7772 - loss: 0.6729 - val_accuracy: 0.5522 - val_loss: 0.9031 - learning_rate: 5.0000e-04
# Epoch 12/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 71s 254ms/step - accuracy: 0.7726 - loss: 0.6516 - val_accuracy: 0.8584 - val_loss: 0.5649 - learning_rate: 5.0000e-04
# Epoch 13/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 83s 258ms/step - accuracy: 0.7558 - loss: 0.6695 - val_accuracy: 0.6043 - val_loss: 1.0807 - learning_rate: 5.0000e-04
# Epoch 14/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 90s 287ms/step - accuracy: 0.7717 - loss: 0.6160 - val_accuracy: 0.8885 - val_loss: 0.4200 - learning_rate: 5.0000e-04
# Epoch 15/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 71s 257ms/step - accuracy: 0.7779 - loss: 0.6157 - val_accuracy: 0.4739 - val_loss: 1.1372 - learning_rate: 5.0000e-04
# Epoch 16/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 71s 256ms/step - accuracy: 0.7836 - loss: 0.6027 - val_accuracy: 0.8719 - val_loss: 0.4682 - learning_rate: 5.0000e-04
# Epoch 17/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 82s 256ms/step - accuracy: 0.7816 - loss: 0.5802 - val_accuracy: 0.6057 - val_loss: 1.0514 - learning_rate: 5.0000e-04
# Epoch 18/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 71s 257ms/step - accuracy: 0.7830 - loss: 0.5922 - val_accuracy: 0.8076 - val_loss: 0.7357 - learning_rate: 5.0000e-04
# Epoch 19/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 81s 255ms/step - accuracy: 0.7577 - loss: 0.6974 - val_accuracy: 0.7932 - val_loss: 0.6423 - learning_rate: 5.0000e-04
# Epoch 20/200
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 81s 253ms/step - accuracy: 0.7829 - loss: 0.5963 - val_accuracy: 0.9263 - val_loss: 0.3186 - learning_rate: 5.0000e-04

# %% [markdown]
# # 9. Predições em ensemble e otimização de threshold

# %%
y_pred_proba_list = [model.predict(X_test_seq) for model in models]
y_pred_proba_avg = np.mean(y_pred_proba_list, axis=0)
# Out:
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 9s 92ms/step
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 9s 83ms/step

# %%
thresholds = np.arange(0.3, 0.7, 0.01)
best_threshold = 0.5
best_accuracy = 0

# %%
for threshold in thresholds:
    y_pred_temp = (y_pred_proba_avg > threshold).astype(int)
    accuracy = accuracy_score(y_test, y_pred_temp)
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_threshold = threshold

print(f"Melhor threshold encontrado: {best_threshold:.3f}")
# Out:
# Melhor threshold encontrado: 0.370

# %%
y_pred = (y_pred_proba_avg > best_threshold).astype(int)

# %% [markdown]
# # 10. Avaliação do modelo

# %%
test_accuracy = accuracy_score(y_test, y_pred)
print(f"\nAcurácia no conjunto de teste: {test_accuracy:.4f}")
# Out:
# Acurácia no conjunto de teste: 0.8977

# %%
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# %%
print(f"Precisão: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
# Out:
# Precisão: 0.8884
# Recall: 0.9869
# F1-Score: 0.9351

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Vender (-1)', 'Comprar (1)'],
            yticklabels=['Vender (-1)', 'Comprar (1)'])
plt.xlabel('Previsão')
plt.ylabel('Real')
plt.title('Matriz de Confusão')
plt.show()

# %%
print("\nRelatório de Classificação:")
print(classification_report(y_test, y_pred, target_names=['Vender (-1)', 'Comprar (1)']))
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#  Vender (-1)       0.94      0.64      0.76       674
#  Comprar (1)       0.89      0.99      0.94      1984
#
#     accuracy                           0.90      2658
#    macro avg       0.92      0.81      0.85      2658
# weighted avg       0.90      0.90      0.89      2658
